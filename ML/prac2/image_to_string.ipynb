# %%
import cv2
import pytesseract
import numpy as np

# %%
img = cv2.imread("image.webp")
text = pytesseract.image_to_string(img)

print(text)
# Out:
#
#
# How to convert a text file
# to a string in python
#
# ke Avnish
# = Mar 31

# %%
img = cv2.imread("image1.jpg")
img = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
text = pytesseract.image_to_string(gray)

print(text)

# %%
img = cv2.imread("image2.jpg")
text = pytesseract.image_to_string(img)

print(text)
# Out:
# Pa
# Methods
#
#
#
#
#
#
#
# Input | Method Output
# hello john’ | -capitatize() | “Helle john”
# “hellojohn” | .upper() “HELLO JOHN”
# "123456" .isnumeric() True
# “hellojohn” | .isupper() False
# “hellojohn” | .title() “Hello John"
# “HiJohn" | .spiit() ['Hi", "John"]
# hello" | .strip() “hello”
# "abx" wreplace(’x'c')| "abe"
#
# |
#
#
#
#
#
#
#
# © Datamavericks Bi Save for later
